# %%
#Importing Pandas,json, json_normalize and numpy
import pandas as pd
import json
from pandas.io.json import json_normalize
import numpy as np

# %%
#changed data/world_bank_projects.json to 'world_bank'. Loaded 'world_bank' as a json file and normalized columns
# 'mjtheme_namecode' and 'countryname'
json_df=json.load((open('world_bank')))
json_normalize(json_df, 'mjtheme_namecode')
json_normalize(json_df, 'mjtheme_namecode', ['countryname'])
# Out:
#      code                                          name  \
# 0       8                             Human development
# 1      11
# 2       1                           Economic management
# 3       6         Social protection and risk management
# 4       5                         Trade and integration
# 5       2                      Public sector governance
# 6      11  Environment and natural resources management
# 7       6         Social protection and risk management
# 8       7                   Social dev/gender/inclusion
# 9       7                   Social dev/gender/inclusion
# 10      5                         Trade and integration
# 11      4      Financial and private sector development
# 12      6         Social protection and risk management
# 13      6
# 14      2                      Public sector governance
# 15      4      Financial and private sector development
# 16     11  Environment and natural resources management
# 17      8
# ...

# %%
# Normalized data frame using 'mjtheme_namecode' and 'countryname'
projects=json_normalize(json_df, 'mjtheme_namecode', ['countryname'])
print(projects)
# Out:
#      code                                          name  \
# 0       8                             Human development
# 1      11
# 2       1                           Economic management
# 3       6         Social protection and risk management
# 4       5                         Trade and integration
# 5       2                      Public sector governance
# 6      11  Environment and natural resources management
# 7       6         Social protection and risk management
# 8       7                   Social dev/gender/inclusion
# 9       7                   Social dev/gender/inclusion
# 10      5                         Trade and integration
# 11      4      Financial and private sector development
# 12      6         Social protection and risk management
# 13      6
# 14      2                      Public sector governance
# 15      4      Financial and private sector development
# 16     11  Environment and natural resources management
# 17      8
# ...

# %%
# changed blank name values to 0 and printed. Len was used because code, name and countryname would have lengths greater than one unless they were blank. 
print (projects.applymap(len))
# Out:
#       code  name  countryname
# 0        1    17           39
# 1        2     0           39
# 2        1    19           19
# 3        1    37           19
# 4        1    21            6
# 5        1    24            6
# 6        2    44            6
# 7        1    37            6
# 8        1    27           17
# 9        1    27           17
# 10       1    21           18
# 11       1    40           18
# 12       1    37           17
# 13       1     0           17
# 14       1    24           17
# 15       1    40           17
# 16       2    44           26
# 17       1     0           26
# 18       2    17           17
# 19       1     0           17
# 20       1    24           18
# 21       1    24           18
# 22       1    24           18
# 23       2    17           23
# 24       1     0           23
# 25       2    17           17
# 26       1    37           17
# 27       1    37           17
# 28       2    44           17
# 29       1     0           17
# ...

# %%
# converted less the 1 length values to NaN using np.nan and printed
projects[projects.applymap(len) < 1]= np.nan
print(projects)
# Out:
#      code                                          name  \
# 0       8                             Human development
# 1      11                                           NaN
# 2       1                           Economic management
# 3       6         Social protection and risk management
# 4       5                         Trade and integration
# 5       2                      Public sector governance
# 6      11  Environment and natural resources management
# 7       6         Social protection and risk management
# 8       7                   Social dev/gender/inclusion
# 9       7                   Social dev/gender/inclusion
# 10      5                         Trade and integration
# 11      4      Financial and private sector development
# 12      6         Social protection and risk management
# 13      6                                           NaN
# 14      2                      Public sector governance
# 15      4      Financial and private sector development
# ...

# %%
# Grouped projects by name using the number of projects and sorted the values in decending order
# listing the top 10 projects using .head(10)
projects.groupby('name').size().sort_values(ascending=False).head(10)
# Out:
# name
# Environment and natural resources management    223
# Rural development                               202
# Human development                               197
# Public sector governance                        184
# Social protection and risk management           158
# Financial and private sector development        130
# Social dev/gender/inclusion                     119
# Trade and integration                            72
# Urban development                                47
# Economic management                              33
# dtype: int64

# %%
# Top ten countries after name of project was changed to NaN
projects['countryname'].value_counts().head(10)
# Out:
# Republic of Indonesia              56
# Republic of India                  51
# Socialist Republic of Vietnam      43
# People's Republic of Bangladesh    41
# Federative Republic of Brazil      41
# People's Republic of China         40
# Africa                             39
# Republic of Yemen                  34
# Kingdom of Morocco                 32
# Republic of Mozambique             31
# Name: countryname, dtype: int64

# %%
# last dataframe, final
final= pd.DataFrame(projects)
print(final)
# Out:
#      code                                          name  \
# 0       8                             Human development
# 1      11                                           NaN
# 2       1                           Economic management
# 3       6         Social protection and risk management
# 4       5                         Trade and integration
# 5       2                      Public sector governance
# 6      11  Environment and natural resources management
# 7       6         Social protection and risk management
# 8       7                   Social dev/gender/inclusion
# 9       7                   Social dev/gender/inclusion
# 10      5                         Trade and integration
# 11      4      Financial and private sector development
# 12      6         Social protection and risk management
# 13      6                                           NaN
# 14      2                      Public sector governance
# 15      4      Financial and private sector development
# ...
